# %%
# %cd ..
# Out:
# c:\Users\HP\OneDrive - University of Moratuwa\Desktop\E-Vision-Projects\DB_SQL_GEN

# %%
from src.core import db_manager
# Out:
# 2026-05-14 12:13:15.468 | INFO     | src.core.database:__init__:26 - Connected to database: mysql+pymysql://root:root_123@localhost:3306/samindu_live

# %%
context = db_manager.get_schema_for_tables(['sales_flat'])
# Out:
# c:\Users\HP\OneDrive - University of Moratuwa\Desktop\E-Vision-Projects\DB_SQL_GEN\.venv\Lib\site-packages\langchain_community\utilities\sql_database.py:363: SAWarning: Cannot correctly sort tables; there are unresolvable cycles between tables "accounts, asset_transfer_history_records, deposit_lines, external_parties, invoice_lines, invoice_templates, invoice_types, invoices, job_cards, job_requests, master_customers, note_association, over_pay_settlements, payment_associations, payments, refunds, routes, sales_hierarchy_nodes, stock_locations, users", which is usually caused by mutually dependent foreign key constraints.  Foreign key constraints involving these tables will not be considered; this warning may raise an error in a future release.
#   metadata_table_names = [tbl.name for tbl in self._metadata.sorted_tables]
# ...

# %%
print(context)
# Out:
# CREATE TABLE sales_flat (
# 	`Date` DATE,
# 	`InvoiceNo` VARCHAR(50),
# 	`ProductCode` VARCHAR(255),
# 	`ProductName` VARCHAR(255),
# 	`Qty` DECIMAL(10, 2),
# 	`Discount` DECIMAL(5, 2),
# 	in_sales DECIMAL(12, 2),
# 	`Brand` VARCHAR(255),
# 	`CustomerCategory` VARCHAR(255),
# 	`ProductCategory` VARCHAR(255),
# 	`Route` VARCHAR(255),
# 	`RepId` INTEGER,
# 	`RepCode` VARCHAR(255),
# 	`RepName` VARCHAR(255),
# 	`CustomerCode` VARCHAR(100),
# 	`CustomerName` VARCHAR(100),
# 	`ASM` VARCHAR(100),
# 	`RSM` VARCHAR(100),
# 	`Distributor` VARCHAR(255),
# 	`Type` VARCHAR(10)
# )DEFAULT CHARSET=utf8mb4 COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB
#
# /*
# 3 rows from sales_flat table:
# Date	InvoiceNo	ProductCode	ProductName	Qty	Discount	in_sales	Brand	CustomerCategory	ProductCategory	Route	RepId	RepCode	RepName	CustomerCode	CustomerName	ASM	RSM	Distributor	Type
# ...

# %%
db_manager.get_table_metadata('sales_flat')
# Out:
# {'name': 'sales_flat',
#  'columns': [{'name': 'Date',
#    'type': DATE(),
#    'default': None,
#    'comment': None,
#    'nullable': True},
#   {'name': 'InvoiceNo',
#    'type': VARCHAR(length=50),
#    'default': None,
#    'comment': None,
#    'nullable': True},
#   {'name': 'ProductCode',
#    'type': VARCHAR(length=255),
#    'default': None,
#    'comment': None,
#    'nullable': True},
#   {'name': 'ProductName',
#    'type': VARCHAR(length=255),
#    'default': None,
#    'comment': None,
#    'nullable': True},
#   {'name': 'Qty',
#    'type': DECIMAL(precision=10, scale=2),
#    'default': None,
#    'comment': None,
#    'nullable': True},
#   {'name': 'Discount',
#    'type': DECIMAL(precision=5, scale=2),
#    'default': None,
#    'comment': None,
#    'nullable': True},
#   {'name': 'in_sales',
#    'type': DECIMAL(precision=12, scale=2),
#    'default': None,
#    'comment': None,
#    'nullable': True},
#   {'name': 'Brand',
#    'type': VARCHAR(length=255),
# ...
